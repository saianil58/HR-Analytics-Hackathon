# %%
from pycaret.classification import *
import pandas as pd
train=pd.read_csv('Train_data.csv')
#intialize the setup
exp_clf = setup(data=train, target = 'is_promoted',Feature_Selection=True)
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
#     #T_52687a74_b537_11ea_9824_54e1ad068252row4_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_52687a74_b537_11ea_9824_54e1ad068252" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_52687a74_b537_11ea_9824_54e1ad068252level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_52687a74_b537_11ea_9824_54e1ad068252row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_52687a74_b537_11ea_9824_54e1ad068252row0_col1" class="data row0 col1" >8711</td>
#             </tr>
#             <tr>
#                         <th id="T_52687a74_b537_11ea_9824_54e1ad068252level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_c0b6367e_b538_11ea_8afd_54e1ad068252 th {
#           text-align: left;
#     }    #T_c0b6367e_b538_11ea_8afd_54e1ad068252row0_col0 {
#             text-align:  left;
#         }    #T_c0b6367e_b538_11ea_8afd_54e1ad068252row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_c0b6367e_b538_11ea_8afd_54e1ad068252row0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_c0b6367e_b538_11ea_8afd_54e1ad068252row0_col3 {
#             : ;
#             text-align:  left;
#         }    #T_c0b6367e_b538_11ea_8afd_54e1ad068252row0_col4 {
#             : ;
#             text-align:  left;
#         }    #T_c0b6367e_b538_11ea_8afd_54e1ad068252row0_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_c0b6367e_b538_11ea_8afd_54e1ad068252row0_col6 {
#             background-color:  yellow;
#             text-align:  left;
# ...

# %%
tuned_rf=tune_model(estimator='rf',
           fold=10,
           round=4,
           n_iter=10,
           optimize='F1',
           ensemble=False,
           method=None,
           verbose=True)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9348  0.8775  0.3144  0.8000  0.4514  0.4237
# 1       0.9293  0.8772  0.2358  0.7826  0.3624  0.3362
# 2       0.9382  0.8892  0.3231  0.8706  0.4713  0.4458
# 3       0.9326  0.8694  0.2576  0.8429  0.3946  0.3695
# 4       0.9345  0.8768  0.2969  0.8193  0.4359  0.4091
# 5       0.9363  0.8778  0.3114  0.8353  0.4537  0.4273
# 6       0.9356  0.8842  0.3289  0.7895  0.4644  0.4362
# 7       0.9352  0.8868  0.3057  0.8235  0.4459  0.4190
# 8       0.9311  0.8692  0.2664  0.7821  0.3974  0.3701
# 9       0.9352  0.8974  0.3100  0.8161  0.4494  0.4222
# Mean    0.9343  0.8805  0.2950  0.8162  0.4326  0.4059
# SD      0.0025  0.0084  0.0294  0.0271  0.0337  0.0335

# %%
tuned_cat=tune_model(estimator='catboost',
           fold=10,
           round=4,
           n_iter=10,
           optimize='F1',
           ensemble=False,
           method=None,
           verbose=True)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9434  0.9044  0.3493  0.9639  0.5128  0.4897
# 1       0.9375  0.9046  0.3013  0.8961  0.4510  0.4264
# 2       0.9427  0.9159  0.3581  0.9213  0.5157  0.4915
# 3       0.9382  0.9069  0.2882  0.9565  0.4430  0.4201
# 4       0.9415  0.9114  0.3450  0.9186  0.5016  0.4773
# 5       0.9415  0.9037  0.3333  0.9383  0.4919  0.4682
# 6       0.9430  0.9059  0.3465  0.9518  0.5080  0.4847
# 7       0.9441  0.9177  0.3755  0.9247  0.5342  0.5100
# 8       0.9412  0.9049  0.3450  0.9080  0.5000  0.4754
# 9       0.9426  0.9182  0.3450  0.9518  0.5064  0.4829
# Mean    0.9416  0.9094  0.3387  0.9331  0.4965  0.4726
# SD      0.0021  0.0056  0.0245  0.0215  0.0270  0.0269

# %%
tuned_lgb=tune_model(estimator='lightgbm',
           fold=10,
           round=4,
           n_iter=10,
           optimize='F1',
           ensemble=False,
           method=None,
           verbose=True)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9356  0.8946  0.3493  0.7692  0.4805  0.4513
# 1       0.9322  0.8948  0.3275  0.7282  0.4518  0.4212
# 2       0.9389  0.9016  0.3712  0.8095  0.5090  0.4812
# 3       0.9341  0.8973  0.3144  0.7826  0.4486  0.4203
# 4       0.9371  0.8966  0.3712  0.7727  0.5015  0.4723
# 5       0.9356  0.8938  0.3465  0.7670  0.4773  0.4482
# 6       0.9374  0.8970  0.3596  0.7885  0.4940  0.4655
# 7       0.9434  0.9103  0.3799  0.8969  0.5337  0.5088
# 8       0.9326  0.8993  0.3319  0.7308  0.4565  0.4259
# 9       0.9423  0.9084  0.3930  0.8491  0.5373  0.5109
# Mean    0.9369  0.8994  0.3545  0.7894  0.4890  0.4605
# SD      0.0036  0.0055  0.0238  0.0489  0.0303  0.0317

# %%
tuned_xgb=tune_model(estimator='xgboost',
           fold=10,
           round=4,
           n_iter=10,
           optimize='F1',
           ensemble=False,
           method=None,
           verbose=True)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9259  0.8902  0.3755  0.6056  0.4636  0.4262
# 1       0.9278  0.8838  0.3537  0.6378  0.4551  0.4198
# 2       0.9330  0.9032  0.3930  0.6870  0.5000  0.4669
# 3       0.9319  0.8847  0.3537  0.6983  0.4696  0.4373
# 4       0.9289  0.8942  0.3843  0.6377  0.4796  0.4439
# 5       0.9292  0.8856  0.3596  0.6508  0.4633  0.4287
# 6       0.9311  0.8897  0.3947  0.6569  0.4932  0.4586
# 7       0.9356  0.9011  0.4236  0.7029  0.5286  0.4963
# 8       0.9307  0.8773  0.3581  0.6777  0.4686  0.4353
# 9       0.9359  0.8905  0.4061  0.7209  0.5196  0.4881
# Mean    0.9310  0.8900  0.3802  0.6676  0.4841  0.4501
# SD      0.0031  0.0075  0.0230  0.0340  0.0240  0.0251

# %%
tuned_gbc=tune_model(estimator='gbc',
           fold=10,
           round=4,
           n_iter=10,
           optimize='F1',
           ensemble=False,
           method=None,
           verbose=True)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9345  0.8882  0.2926  0.8272  0.4323  0.4058
# 1       0.9293  0.8743  0.2533  0.7532  0.3791  0.3512
# 2       0.9341  0.8950  0.2926  0.8171  0.4309  0.4041
# 3       0.9322  0.8831  0.2445  0.8615  0.3810  0.3567
# 4       0.9348  0.8861  0.3013  0.8214  0.4409  0.4141
# 5       0.9359  0.8872  0.2895  0.8684  0.4342  0.4091
# 6       0.9341  0.8855  0.2807  0.8312  0.4197  0.3937
# 7       0.9367  0.8978  0.3231  0.8315  0.4654  0.4386
# 8       0.9345  0.8811  0.2969  0.8193  0.4359  0.4091
# 9       0.9337  0.8921  0.2926  0.8072  0.4295  0.4024
# Mean    0.9340  0.8871  0.2867  0.8238  0.4249  0.3985
# SD      0.0019  0.0065  0.0217  0.0298  0.0250  0.0249

# %%
tuned_lda=tune_model(estimator='lda',
           fold=10,
           round=4,
           n_iter=10,
           optimize='F1',
           ensemble=False,
           method=None,
           verbose=True)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9311  0.8525  0.2707  0.7750  0.4013  0.3736
# 1       0.9281  0.8358  0.2751  0.7000  0.3950  0.3644
# 2       0.9326  0.8693  0.2926  0.7791  0.4254  0.3973
# 3       0.9330  0.8475  0.2620  0.8451  0.4000  0.3748
# 4       0.9356  0.8593  0.2882  0.8684  0.4328  0.4076
# 5       0.9345  0.8394  0.3114  0.7889  0.4465  0.4186
# 6       0.9341  0.8525  0.2895  0.8148  0.4272  0.4005
# 7       0.9352  0.8734  0.3188  0.8022  0.4562  0.4285
# 8       0.9311  0.8405  0.3057  0.7292  0.4308  0.4006
# 9       0.9371  0.8726  0.3100  0.8659  0.4566  0.4310
# Mean    0.9332  0.8543  0.2924  0.7968  0.4272  0.3997
# SD      0.0025  0.0132  0.0181  0.0523  0.0214  0.0219

# %%
tuned_xgb=calibrate_model(tuned_lgb)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9404  0.9053  0.3450  0.8876  0.4969  0.4716
# 1       0.9375  0.8972  0.3144  0.8675  0.4615  0.4360
# 2       0.9408  0.9096  0.3493  0.8889  0.5016  0.4764
# 3       0.9367  0.9002  0.2969  0.8831  0.4444  0.4195
# 4       0.9393  0.9044  0.3668  0.8235  0.5076  0.4802
# 5       0.9400  0.8993  0.3158  0.9351  0.4721  0.4485
# 6       0.9404  0.9007  0.3465  0.8778  0.4969  0.4715
# 7       0.9441  0.9115  0.3668  0.9438  0.5283  0.5047
# 8       0.9397  0.9044  0.3275  0.9036  0.4808  0.4561
# 9       0.9438  0.9085  0.3668  0.9333  0.5266  0.5027
# Mean    0.9403  0.9041  0.3396  0.8944  0.4917  0.4667
# SD      0.0022  0.0045  0.0236  0.0345  0.0257  0.0258

# %%
test=pd.read_csv('Test_data.csv')

# %%
submission_df=predict_model(estimator=tuned_xgb,data=test)

# %%
submission_df[submission_df['Score']>.3]
# Out:
#        employee_id         department     region         education gender  \
# 10           60245  Sales & Marketing  region_16        Bachelor's      m
# 32           67672         Technology  region_17        Bachelor's      m
# 54           21379         Technology   region_4        Bachelor's      m
# 78           10732          Analytics   region_2        Bachelor's      m
# 118          27495         Operations   region_2  Master's & above      m
# ...            ...                ...        ...               ...    ...
# 23387        29019          Analytics  region_22        Bachelor's      m
# 23394        70977        Procurement   region_2   Below Secondary      m
# 23422        22396         Operations  region_19  Master's & above      m
# 23454        55030  Sales & Marketing  region_28  Master's & above      m
# 23489         5973         Technology  region_17  Master's & above      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
cols=['employee_id','Label']

# %%
sub_df=submission_df[cols]

# %%
sub_df.to_csv('pycaret.csv',index=False)
